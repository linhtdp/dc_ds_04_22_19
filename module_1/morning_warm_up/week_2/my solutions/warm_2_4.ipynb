# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
A=np.random.normal(size=100)

# %%
np.random.normal?

# %%
plt.hist(A)
# Out:
# (array([ 1.,  2.,  2., 11., 15., 27., 21., 11.,  6.,  4.]),
#  array([-3.24125002, -2.67737739, -2.11350476, -1.54963214, -0.98575951,
#         -0.42188688,  0.14198575,  0.70585837,  1.269731  ,  1.83360363,
#          2.39747626]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(A)
# Out:
# (array([ 1.,  2.,  2., 11., 15., 27., 21., 11.,  6.,  4.]),
#  array([-3.24125002, -2.67737739, -2.11350476, -1.54963214, -0.98575951,
#         -0.42188688,  0.14198575,  0.70585837,  1.269731  ,  1.83360363,
#          2.39747626]),
#  <a list of 10 Patch objects>)

# %%
sns.distplot(A)

# %%
sns.distplot(A)
plt.title("Normal Distribution with Seaborn")
plt.savefig('hist_sns.png')

# %%
weights = np.random.normal(scale=2,size=100)
noise = np.random.normal(scale=0.1,size=100)
x = 5
y = weights*x + noise

# %%
e
